# %%
# !git clone https://github.com/rimshaausaf/ATML-PA1.git
# %cd ATML-PA1
# Out:
# Cloning into 'ATML-PA1'...
# remote: Enumerating objects: 10728, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 10728 (delta 0), reused 0 (delta 0), pack-reused 10726 (from 1)
# Receiving objects: 100% (10728/10728), 179.53 MiB | 17.21 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Updating files: 100% (10812/10812), done.
# /content/ATML-PA1

# %%
# !mkdir -p common
# !mkdir -p task1/configs task1/data task1/models task1/analysis task1/scripts task1/results

# %%
# !pip install open_clip_torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/ATML-PA1
# !python task1/data/make_subset.py
# Out:
# /content/ATML-PA1
# 100% 2.64G/2.64G [02:33<00:00, 17.2MB/s]
# Saved 500 balanced indices to task1/data/stl10_test_subset_indices.json

# %%
# %cd /content/ATML-PA1
# !git config --global user.email "rimshaausaf1122@gmail.com"
# !git config --global user.name "Rimsha Ausaf"
# Out:
# /content/ATML-PA1

# %%
# !rm -rf .git

# !echo -e "__pycache__/\n*.pt\n*.pth\ndata/stl10_binary/\ndata/*.tar.gz" > .gitignore

# !git init
# !git branch -M main
# !git add .
# !git commit -m "Task 1"

# !git remote add origin https://rimshaausaf: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@github.com/rimshaausaf/ATML-PA1.git
# !git push -u origin main --force
# Out:
# Streaming output truncated to the last 5000 lines.
#  create mode 100644 data/pacs/PACS/photo/person/253_0190.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0191.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0192.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0193.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0194.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0195.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0196.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0197.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0198.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0199.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0200.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0201.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0202.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0203.jpg
#  create mode 100644 data/pacs/PACS/photo/person/253_0204.jpg
# ...

# %%
# !python -m task1.scripts.run_task1
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 180MB/s]
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100% 330M/330M [00:01<00:00, 176MB/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# open_clip_model.safetensors: downloading bytes:  49% 296M/605M [00:01<00:02, 149MB/s, 25.9MB/s  ]
# open_clip_model.safetensors: downloading bytes:  71% 431M/605M [00:02<00:01, 148MB/s, 36.0MB/s  ]
# open_clip_model.safetensors: reconstructing file:  78% 470M/605M [00:03<00:00, 155MB/s, 25.3MB/s  ]
# open_clip_model.safetensors: downloading bytes: 100% 432M/432M [00:05<00:00, 72.7MB/s, 36.3MB/s  ]
# ...

# %%
# !python -m task1.scripts.train_heads
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#
# --- Training ResNet Head ---
# Epoch 01 | Train Loss: 1.0865 | Val Acc: 94.60%
# Epoch 02 | Train Loss: 0.3368 | Val Acc: 95.20%
# Epoch 03 | Train Loss: 0.2025 | Val Acc: 95.50%
# Epoch 04 | Train Loss: 0.1469 | Val Acc: 95.90%
# Epoch 05 | Train Loss: 0.1156 | Val Acc: 96.30%
# Epoch 06 | Train Loss: 0.0950 | Val Acc: 96.40%
# Epoch 07 | Train Loss: 0.0797 | Val Acc: 96.20%
# Epoch 08 | Train Loss: 0.0682 | Val Acc: 96.30%
# Epoch 09 | Train Loss: 0.0590 | Val Acc: 96.50%
# Epoch 10 | Train Loss: 0.0513 | Val Acc: 96.40%
# Epoch 11 | Train Loss: 0.0458 | Val Acc: 96.30%
# ...

# %%
# !python -m task1.analysis.evaluate_bias
# Out:
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# --- ResNet (Trained Head) ---
# Top-1 Accuracy: 96.00%
# Macro-F1 Score: 0.9601
# Mean Max Confidence: 0.9489
#
# --- ViT (Trained Head) ---
# Top-1 Accuracy: 95.80%
# Macro-F1 Score: 0.9580
# Mean Max Confidence: 0.9335
#
# --- CLIP (Trained Head) ---
# Top-1 Accuracy: 92.80%
# Macro-F1 Score: 0.9277
# Mean Max Confidence: 0.6088
#
# --- Zero-Shot CLIP ---
# Top-1 Accuracy: 87.60%
# Macro-F1 Score: 0.8713
# Mean Max Confidence: 0.8721

# %%
# !python -m task1.analysis.color_bias
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#
# [ResNet]
# Clean Accuracy: 96.00%
# Grayscale Accuracy: 90.80% (Drop: 5.20%) | Consistency: 92.60%
# Hue Rotation Accuracy: 90.80% (Drop: 5.20%) | Consistency: 93.20%
#
# [ViT]
# Clean Accuracy: 95.80%
# Grayscale Accuracy: 92.80% (Drop: 3.00%) | Consistency: 95.40%
# Hue Rotation Accuracy: 92.80% (Drop: 3.00%) | Consistency: 95.00%
#
# [CLIP]
# Clean Accuracy: 92.80%
# Grayscale Accuracy: 85.00% (Drop: 7.80%) | Consistency: 89.20%
# Hue Rotation Accuracy: 87.80% (Drop: 5.00%) | Consistency: 92.00%

# %%
# !python -m task1.data.make_cue_conflicts
# Out:
# Saved 250 image pairs to task1/data/cue_conflicts/.

# %%
# !python -m task1.analysis.shape_bias
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# --- Shape Bias & Coverage Evaluation (250 Images) ---
#
# [ResNet]
# Decisions -> Shape: 31 | Texture: 20 | Other: 199
# Shape Bias: 60.78%
# Coverage: 20.40%
#
# [ViT]
# Decisions -> Shape: 27 | Texture: 23 | Other: 200
# Shape Bias: 54.00%
# Coverage: 20.00%
#
# [CLIP]
# Decisions -> Shape: 26 | Texture: 19 | Other: 205
# Shape Bias: 57.78%
# Coverage: 18.00%

# %%
# !python -m task1.analysis.spatial_translation
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# [ResNet] Shift 0px -> Accuracy: 96.00%
# [ResNet] Shift 8px -> Accuracy: 95.80%
# [ResNet] Shift 16px -> Accuracy: 95.00%
# [ResNet] Shift 32px -> Accuracy: 94.20%
# [ViT] Shift 0px -> Accuracy: 95.80%
# [ViT] Shift 8px -> Accuracy: 95.80%
# [ViT] Shift 16px -> Accuracy: 96.60%
# [ViT] Shift 32px -> Accuracy: 95.80%
# [CLIP] Shift 0px -> Accuracy: 92.80%
# [CLIP] Shift 8px -> Accuracy: 91.00%
# [CLIP] Shift 16px -> Accuracy: 90.40%
# [CLIP] Shift 32px -> Accuracy: 83.60%
#
# Figure dynamically saved to task1/analysis/figures/spatial_translation.png

# %%
# !python -m task1.analysis.patch_shuffling
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# [ResNet] Clean: 96.00% | Shuffled: 23.40% | Drop: 72.60% | Consistency: 23.20%
# [ViT] Clean: 95.80% | Shuffled: 28.40% | Drop: 67.40% | Consistency: 28.80%
# [CLIP] Clean: 92.80% | Shuffled: 13.80% | Drop: 79.00% | Consistency: 13.60%
#
# Figure dynamically saved to task1/analysis/figures/patch_shuffling.png

# %%
# !python -m task1.analysis.representation_stability
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# [ResNet] Clean vs Grayscale Sim: 0.7646
# [ResNet] Clean vs Shifted Sim: 0.9466
# [ViT] Clean vs Grayscale Sim: 0.7496
# [ViT] Clean vs Shifted Sim: 0.8800
# [CLIP] Clean vs Grayscale Sim: 0.9301
# [CLIP] Clean vs Shifted Sim: 0.9315
#
# Generating t-SNE plot for CLIP...
# t-SNE saved to 'task1/analysis/figures/clip_tsne.png'

# %%
# !python -m task1.analysis.zero_shot_clip
# Out:
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# Zero-Shot Clean Accuracy: 94.00%
# Linear Probe Clean Accuracy: 92.80% (From previous experiments)

# %%
# !git add .
# !git commit -m "Task 1"
# !git push
# Out:
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> pytorch-AdaIN
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached pytorch-AdaIN
# hint:
# hint: See "git help submodule" for more information.
# [main e93e753] Task 1
#  1 file changed, 1 insertion(+)
#  create mode 160000 pytorch-AdaIN
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 336 bytes | 336.00 KiB/s, done.
# Total 2 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/rimshaausaf/ATML-PA1.git
#    858de34..e93e753  main -> main

# %%
# !pwd
# Out:
# /content/ATML-PA1

# %%
# !python -m task2.train --method source_only
# !python -m task2.train --method dan
# !python -m task2.train --method cdan
# !python -m task2.train --method dann --max_alpha 0.25
# !python -m task2.train --method dann --max_alpha 0.5
# !python -m task2.train --method dann --max_alpha 1.0
# Out:
# Starting SOURCE_ONLY training on cuda (Max Alpha: 1.0)...
# Epoch 01 | Cls Loss: 0.5367 | Dom Loss: 0.0000 | Mean Source F1: 88.60%
# Epoch 02 | Cls Loss: 0.2449 | Dom Loss: 0.0000 | Mean Source F1: 81.76%
# Epoch 03 | Cls Loss: 0.2043 | Dom Loss: 0.0000 | Mean Source F1: 92.77%
# Epoch 04 | Cls Loss: 0.1611 | Dom Loss: 0.0000 | Mean Source F1: 88.74%
# Epoch 05 | Cls Loss: 0.1168 | Dom Loss: 0.0000 | Mean Source F1: 93.02%
# Epoch 06 | Cls Loss: 0.0870 | Dom Loss: 0.0000 | Mean Source F1: 92.44%
# Epoch 07 | Cls Loss: 0.0993 | Dom Loss: 0.0000 | Mean Source F1: 92.02%
# Epoch 08 | Cls Loss: 0.0971 | Dom Loss: 0.0000 | Mean Source F1: 94.46%
# Epoch 09 | Cls Loss: 0.0659 | Dom Loss: 0.0000 | Mean Source F1: 92.94%
# Epoch 10 | Cls Loss: 0.0892 | Dom Loss: 0.0000 | Mean Source F1: 94.13%
# Epoch 11 | Cls Loss: 0.0540 | Dom Loss: 0.0000 | Mean Source F1: 84.21%
# Epoch 12 | Cls Loss: 0.0724 | Dom Loss: 0.0000 | Mean Source F1: 93.39%
# ...

# %%
# !python -m task2.evaluate_final
# Out:
# Evaluating SOURCE_ONLY...
# Target Accuracy: 59.94%, Target F1: 50.97%, Separability: 99.59%
#
# Evaluating DAN...
#
# --- Class Transfer Analysis (DAN vs. Source-only) ---
#   Class dog       : Source-only = 40.67%, DAN = 40.41% (Δ = -0.26%)
#   Class elephant  : Source-only = 51.89%, DAN = 73.65% (Δ = +21.76%)
#   Class giraffe   : Source-only = 87.38%, DAN = 44.75% (Δ = -42.63%)
#   Class guitar    : Source-only = 82.24%, DAN = 75.66% (Δ = -6.58%)
#   Class horse     : Source-only = 55.51%, DAN = 58.21% (Δ = +2.70%)
#   Class house     : Source-only = 8.75%, DAN = 100.00% (Δ = +91.25%)
#   Class person    : Source-only = 24.38%, DAN = 56.25% (Δ = +31.88%)
#
# Largest Improvement: house (+91.25%)
# Largest Degradation / Stagnation: giraffe (-42.63%)
# Dominant confusion for giraffe: misclassified as person (231 times)
# Target Accuracy: 58.51%, Target F1: 55.62%, Separability: 83.93%
#
# Evaluating DANN...
# ...

# %%
# !python task2/plot_figures.py
# Out:
# Saved task2_loss_curves.png
# Saved task2_dann_study.png

# %%
# !git add .
# !git commit -m "Task 2"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !mkdir -p task3/configs task3/models task3/methods task3/selection task3/evaluation task3/results

# %%
# !python -m task3.train --method dan_dg --lambda_dg 1.0
# Out:
# Starting Task 3 [DAN_DG_LAMBDA1.0] training on cuda...
# Epoch 01 | Cls: 1.7659 | MMD: 0.4140 | Mean F1: 14.88% | Worst F1: 8.18%
# Epoch 02 | Cls: 1.9369 | MMD: 0.3871 | Mean F1: 5.07% | Worst F1: 4.21%
# Epoch 03 | Cls: 1.9365 | MMD: 0.3992 | Mean F1: 3.90% | Worst F1: 2.93%
# Epoch 04 | Cls: 1.9271 | MMD: 0.3925 | Mean F1: 5.07% | Worst F1: 4.22%
# Epoch 05 | Cls: 1.9233 | MMD: 0.3847 | Mean F1: 5.07% | Worst F1: 4.21%
# Epoch 06 | Cls: 1.9202 | MMD: 0.3732 | Mean F1: 5.39% | Worst F1: 3.97%
# Early stopping triggered after 6 epochs.
# Saved best model checkpoint to task3/results/dan_dg_lambda1.0_best.pth

# %%
# !python -m task3.train --method sam --rho 0.05
# Out:
# Starting Task 3 [SAM_RHO0.05] training on cuda...
# Epoch 01 | Cls: 0.8879 | MMD: 0.0000 | Mean F1: 89.35% | Worst F1: 85.93%
# Epoch 02 | Cls: 0.2652 | MMD: 0.0000 | Mean F1: 91.87% | Worst F1: 86.66%
# Epoch 03 | Cls: 0.1749 | MMD: 0.0000 | Mean F1: 93.86% | Worst F1: 90.01%
# Epoch 04 | Cls: 0.1188 | MMD: 0.0000 | Mean F1: 92.88% | Worst F1: 88.77%
# Epoch 05 | Cls: 0.0960 | MMD: 0.0000 | Mean F1: 93.01% | Worst F1: 90.20%
# Epoch 06 | Cls: 0.0622 | MMD: 0.0000 | Mean F1: 94.68% | Worst F1: 91.39%
# Epoch 07 | Cls: 0.0475 | MMD: 0.0000 | Mean F1: 93.94% | Worst F1: 89.56%
# Epoch 08 | Cls: 0.0386 | MMD: 0.0000 | Mean F1: 94.30% | Worst F1: 89.91%
# Epoch 09 | Cls: 0.0299 | MMD: 0.0000 | Mean F1: 95.30% | Worst F1: 93.27%
# Epoch 10 | Cls: 0.0238 | MMD: 0.0000 | Mean F1: 95.23% | Worst F1: 91.71%
# Epoch 11 | Cls: 0.0232 | MMD: 0.0000 | Mean F1: 94.06% | Worst F1: 89.67%
# Epoch 12 | Cls: 0.0179 | MMD: 0.0000 | Mean F1: 95.36% | Worst F1: 93.60%
# ...

# %%
# !python -m task3.train --method dan_dg --lambda_dg 0.1
# Out:
# Starting Task 3 [DAN_DG_LAMBDA0.1] training on cuda...
# Epoch 01 | Cls: 0.5137 | MMD: 0.5095 | Mean F1: 85.62% | Worst F1: 82.42%
# Epoch 02 | Cls: 0.2241 | MMD: 0.4932 | Mean F1: 88.60% | Worst F1: 82.90%
# Epoch 03 | Cls: 0.1645 | MMD: 0.5020 | Mean F1: 94.68% | Worst F1: 91.83%
# Epoch 04 | Cls: 0.1157 | MMD: 0.4743 | Mean F1: 93.57% | Worst F1: 89.72%
# Epoch 05 | Cls: 0.1287 | MMD: 0.4459 | Mean F1: 89.59% | Worst F1: 83.13%
# Epoch 06 | Cls: 0.0855 | MMD: 0.4387 | Mean F1: 92.88% | Worst F1: 89.37%
# Epoch 07 | Cls: 0.0863 | MMD: 0.4375 | Mean F1: 87.12% | Worst F1: 84.23%
# Epoch 08 | Cls: 0.0905 | MMD: 0.4241 | Mean F1: 93.30% | Worst F1: 90.06%
# Early stopping triggered after 8 epochs.
# Saved best model checkpoint to task3/results/dan_dg_lambda0.1_best.pth

# %%
# !python -m task3.train --method dan_dg --lambda_dg 10.0
# Out:
# Starting Task 3 [DAN_DG_LAMBDA10.0] training on cuda...
# Epoch 01 | Cls: 2.1294 | MMD: 0.3893 | Mean F1: 5.07% | Worst F1: 4.22%
# Epoch 02 | Cls: 2.3885 | MMD: 0.3752 | Mean F1: 3.82% | Worst F1: 2.92%
# Epoch 03 | Cls: 2.1015 | MMD: 0.3813 | Mean F1: 3.56% | Worst F1: 2.55%
# Epoch 04 | Cls: 2.2107 | MMD: 0.3573 | Mean F1: 4.63% | Worst F1: 3.51%
# Epoch 05 | Cls: 2.2174 | MMD: 0.3649 | Mean F1: 12.31% | Worst F1: 9.69%
# Epoch 06 | Cls: 2.0824 | MMD: 0.3635 | Mean F1: 3.82% | Worst F1: 2.92%
# Epoch 07 | Cls: 2.0953 | MMD: 0.3686 | Mean F1: 7.30% | Worst F1: 6.07%
# Epoch 08 | Cls: 2.2409 | MMD: 0.3774 | Mean F1: 5.26% | Worst F1: 3.64%
# Epoch 09 | Cls: 1.9554 | MMD: 0.3731 | Mean F1: 5.07% | Worst F1: 4.21%
# Epoch 10 | Cls: 1.9356 | MMD: 0.3676 | Mean F1: 5.07% | Worst F1: 4.21%
# Early stopping triggered after 10 epochs.
# Saved best model checkpoint to task3/results/dan_dg_lambda10.0_best.pth

# %%
# !python -m task3.evaluate_sketch
# Out:
# Evaluating ERM from task2/results/source_only_alpha1.0_best.pth...
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#
# Evaluating DAN-DG from task3/results/dan_dg_lambda1.0_best.pth...
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
# !python task3/plot_figures.py
# Out:
# Saved task3_loss_curves.png
# Saved task3_controlled_study.png

# %%
# !git add .
# !git commit -m "Task 3"
# !git push
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@dede8797b165.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !mkdir -p task4/data task4/models task4/methods task4/scores task4/cache task4/evaluation task4/results

# %%
# !python -m task4.train --method vanilla
# Out:
# Starting VANILLA training...
# Epoch 10/100 | Val Acc: 73.16% (Best: 82.08%)
# Epoch 20/100 | Val Acc: 85.18% (Best: 85.18%)
# Epoch 30/100 | Val Acc: 86.48% (Best: 86.48%)
# Epoch 40/100 | Val Acc: 86.38% (Best: 86.48%)
# Epoch 50/100 | Val Acc: 88.50% (Best: 88.50%)
# Epoch 60/100 | Val Acc: 88.62% (Best: 91.54%)
# Epoch 70/100 | Val Acc: 91.74% (Best: 92.62%)
# Epoch 80/100 | Val Acc: 93.76% (Best: 94.02%)
# Epoch 90/100 | Val Acc: 94.96% (Best: 95.12%)
# Epoch 100/100 | Val Acc: 95.30% (Best: 95.34%)

# %%
# !python -m task4.train --method gcsc
# Out:
# Starting GCSC training...
# Epoch 10/100 | Val Acc: 76.30% (Best: 79.06%)
# Epoch 20/100 | Val Acc: 79.82% (Best: 84.92%)
# Epoch 30/100 | Val Acc: 86.78% (Best: 86.78%)
# Epoch 40/100 | Val Acc: 86.86% (Best: 86.96%)
# Epoch 50/100 | Val Acc: 87.16% (Best: 88.18%)
# Epoch 60/100 | Val Acc: 90.10% (Best: 90.40%)
# Epoch 70/100 | Val Acc: 92.56% (Best: 92.56%)
# Epoch 80/100 | Val Acc: 94.30% (Best: 94.30%)
# Epoch 90/100 | Val Acc: 95.42% (Best: 95.58%)
# Epoch 100/100 | Val Acc: 95.66% (Best: 95.84%)

# %%
# !python -m task4.evaluate_osr --method vanilla
# Out:
# --- Extracting Features for VANILLA ---
#
# Closed-Set Accuracy (CSA): 94.80%
# Score           | Near AUROC   | Far AUROC    | Near FPR@95  | Far FPR@95
# ----------------------------------------------------------------------
# MSP             | 81.03        | 89.29        | 76.62        | 60.25
# MLS             | 79.70        | 88.56        | 73.12        | 51.75
# Energy          | 79.72        | 88.59        | 72.75        | 50.50
# Mahalanobis     | 79.44        | 92.49        | 74.62        | 45.50

# %%
# !python -m task4.evaluate_osr --method gcsc
# Out:
# --- Extracting Features for GCSC ---
#
# Closed-Set Accuracy (CSA): 95.11%
# Score           | Near AUROC   | Far AUROC    | Near FPR@95  | Far FPR@95
# ----------------------------------------------------------------------
# MLS             | 81.07        | 90.21        | 65.25        | 43.75

# %%
# !python -m task4.train_proser
# Out:
# Starting PROSER Fine-Tuning (50 epochs)...
# Epoch 10/50 | Val CSA: 94.96% (Best: 95.06%)
# Epoch 20/50 | Val CSA: 94.94% (Best: 95.08%)
# Epoch 30/50 | Val CSA: 94.84% (Best: 95.20%)
# Epoch 40/50 | Val CSA: 94.94% (Best: 95.20%)
# Epoch 50/50 | Val CSA: 94.98% (Best: 95.20%)

# %%
# !python -m task4.evaluate_osr --method proser
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/ATML-PA1/task4/evaluate_osr.py", line 57, in <module>
#     evaluate_model(args.method)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/content/ATML-PA1/task4/evaluate_osr.py", line 17, in evaluate_model
#     model.load_state_dict(torch.load(f"task4/results/{method}_best.pth", map_location=device, weights_only=True))
#                           ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/serialization.py", line 1530, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ~~~~~~~~~~~~~~~^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/serialization.py", line 795, in _open_file_like
#     return _open_file(name_or_buffer, mode)
# ...

# %%
# !python -m task4.evaluation.plot_osr

# %%
# !git add .
# !git commit -m "Task 4"
# !git push
